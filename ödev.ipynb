# %%
import pandas as pd

# %%
df = pd.read_csv("ChocolateSales.csv")

# %%
df
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %% [markdown]
# Head foksiniyonu(Baştan 5 satırı yazdırır)

# %%
df.head()
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %% [markdown]
# Tail foksiniyonu(Sondan 5 satırı yazdırır)

# %%
df.tail()
# Out:
#           Sales Person    Country              Product       Date   Amount  \
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22  $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22  $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22    $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22  $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22  $5,075
#
#       Boxes Shipped
# 1089            323
# 1090            119
# 1091            217
# 1092            384
# 1093            344

# %% [markdown]
# isnull fonksiyonu(DataFrame’deki NaN değerleri True/False olarak gösterir.)

# %%
df.isnull()
# Out:
#       Sales Person  Country  Product   Date  Amount  Boxes Shipped
# 0            False    False    False  False   False          False
# 1            False    False    False  False   False          False
# 2            False    False    False  False   False          False
# 3            False    False    False  False   False          False
# 4            False    False    False  False   False          False
# ...            ...      ...      ...    ...     ...            ...
# 1089         False    False    False  False   False          False
# 1090         False    False    False  False   False          False
# 1091         False    False    False  False   False          False
# 1092         False    False    False  False   False          False
# 1093         False    False    False  False   False          False
#
# [1094 rows x 6 columns]

# %% [markdown]
# Sum donksiyonu(Sayaç gibi bir başka fonksiyonla kullanıldığında ne kadar parametre olduğunu gösterir)

# %%
df.isnull().sum()
# Out:
# Sales Person     0
# Country          0
# Product          0
# Date             0
# Amount           0
# Boxes Shipped    0
# dtype: int64

# %% [markdown]
# fillna fonksiyonu (Boş değerlerin yerine parantezin içine girilen değeri yerleştirir)

# %%
df.fillna(0)
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %% [markdown]
# dropna(Satır veya sütunü siler)

# %%
df.dropna(axis=0, how="any", inplace=False)
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %% [markdown]
# describe(İstatistiksel özet verir)

# %%
df.describe()
# Out:
#        Boxes Shipped
# count    1094.000000
# mean      161.797989
# std       121.544145
# min         1.000000
# 25%        70.000000
# 50%       135.000000
# 75%       228.750000
# max       709.000000

# %% [markdown]
# groupby(Veriyi gruplar)

# %%
df.groupby("Country").sum()
# Out:
#                                                   Sales Person  \
# Country
# Australia    Jan MorforthGunar CockshootBrien BoiseBeverie ...
# Canada       Mallorie WaberVan TuxwellBeverie MoffetRoddy S...
# India        Van TuxwellGigi BohlingVan TuxwellKarlen McCaf...
# New Zealand  Jehu RudeforthKarlen McCaffreyMarney O'BreenDe...
# UK           Jehu RudeforthJehu RudeforthOby SorrelRafaelit...
# USA          Barr FaughnyRoddy SpeechleyGunar CockshootMarn...
#
#                                                        Product  \
# Country
# Australia    Peanut Butter CubesAfter Nines99% Dark & PureO...
# Canada       EclairsOrganic Choco SyrupMilk BarsSpicy Speci...
# India        85% Dark BarsPeanut Butter CubesSmooth Sliky S...
# New Zealand  50% Dark BitesDrinking CocoPeanut Butter Cubes...
# UK           Mint Chip ChocoPeanut Butter Cubes99% Dark & P...
# USA          Orange ChocoSmooth Sliky SaltySpicy Special Sl...
#
# ...

# %% [markdown]
# isin(belirli bir sütunda belirli bir değree sahip satırların seçilmesinİ sağlar.)

# %%
df2 = df[df["Country"].isin(["İNDİA", "USA"])]
df2
# Out:
#              Sales Person Country              Product       Date    Amount  \
# 11           Barr Faughny     USA         Orange Choco  10-Mar-22   $3,703
# 17        Roddy Speechley     USA   Smooth Sliky Salty  05-Apr-22   $3,017
# 21        Gunar Cockshoot     USA  Spicy Special Slims  17-Feb-22   $1,267
# 22         Marney O'Breen     USA          After Nines  30-May-22   $4,753
# 27           Husein Augar     USA              Eclairs  07-Jul-22   $4,025
# ...                   ...     ...                  ...        ...       ...
# 1062  Dennison Crosswaite     USA       70% Dark Bites  15-Mar-22     $658
# 1064         Gigi Bohling     USA       70% Dark Bites  14-Jan-22   $7,364
# 1081  Dennison Crosswaite     USA   Smooth Sliky Salty  12-May-22  $11,781
# 1082          Brien Boise     USA      Raspberry Choco  12-Jan-22     $672
# 1090       Jehu Rudeforth     USA           White Choc  07-Jun-22   $6,559
#
#       Boxes Shipped
# 11               11
# 17              140
# ...

# %% [markdown]
# astype fonksiyonu (Değerin değişken tipini değiştirir)

# %% [markdown]
# replace fonksiyonu (Fonksiyonun değeri içinde $ işareti gi istenmeyen karakteri silmeye yarar)

# %%
df["Amount"] = df["Amount"].astype(str).str.replace("[$,]"," ", regex = True)
df["Amount"]
# Out:
# 0         5 320
# 1         7 896
# 2         4 501
# 3        12 726
# 4        13 685
#           ...
# 1089      4 410
# 1090      6 559
# 1091        574
# 1092      2 086
# 1093      5 075
# Name: Amount, Length: 1094, dtype: object
